# %% [markdown]
# - Example code for first commit to OCW repo (-Dmitri Kalashnikov)

# %%
for k in range(5):
    print('Hello World!')
# Out:
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
